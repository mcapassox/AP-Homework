# %%
# %pylab inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = [10,20,40,60,80,100,500,1000,5000,10000,30000]
array = [3E-06,4E-06,1.3E-05,3.1E-05,5.4E-05,8.6E-05,0.001811,0.006231,0.16142,0.642324,5.804237]
heap = [6E-06,5E-06,3E-05,2.7E-05,4.5E-05,6.8E-05,0.000936,0.00407,0.12697,0.524699,4.778301]

# %%
plot(x, array)
plot(x, heap)

ylabel('Running time (s) ')
xlabel('Size of Array')
title('Running time (d = 1,000,000)')
legend(['insertion', 'quick', 'counting', 'radix', 'bucket', 'select', 'heap'])
#savefig('running_time_averaged6.pdf')
